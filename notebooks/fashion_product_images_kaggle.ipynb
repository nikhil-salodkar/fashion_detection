# %%
import numpy as np
import pandas as pd
import os

# %%
data_path = os.path.join('../data/fashion-dataset/')

# %%
image_df = pd.read_csv(os.path.join(data_path, 'images.csv'))

# %%
image_df.head()
# Out:
#     filename                                               link
# 0  15970.jpg  http://assets.myntassets.com/v1/images/style/p...
# 1  39386.jpg  http://assets.myntassets.com/v1/images/style/p...
# 2  59263.jpg  http://assets.myntassets.com/v1/images/style/p...
# 3  21379.jpg  http://assets.myntassets.com/v1/images/style/p...
# 4  53759.jpg  http://assets.myntassets.com/v1/images/style/p...

# %%
image_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  44446 non-null  object
#  1   link      44446 non-null  object
# dtypes: object(2)
# memory usage: 694.6+ KB

# %%
styles_df = pd.read_csv(os.path.join(data_path, 'styles.csv'), on_bad_lines='skip')

# %%
styles_df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
# Some are Null for product Display name, usage
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44425 entries, 0 to 44424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44425 non-null  int64
#  1   gender              44425 non-null  object
#  2   masterCategory      44425 non-null  object
#  3   subCategory         44425 non-null  object
#  4   articleType         44425 non-null  object
#  5   baseColour          44410 non-null  object
#  6   season              44404 non-null  object
#  7   year                44424 non-null  float64
#  8   usage               44108 non-null  object
#  9   productDisplayName  44418 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.4+ MB

# %%
# unique master categories
print(np.unique(styles_df.masterCategory))
# Out:
# ['Accessories' 'Apparel' 'Footwear' 'Free Items' 'Home' 'Personal Care'
#  'Sporting Goods']

# %%
# master categories distribution.. Home, sporting goods and free items are very less in number
styles_df.groupby('masterCategory')['masterCategory'].count()
# Out:
# masterCategory
# Accessories       11274
# Apparel           21397
# Footwear           9219
# Free Items          105
# Home                  1
# Personal Care      2404
# Sporting Goods       25
# Name: masterCategory, dtype: int64

# %%
# lets remove these
styles_df = styles_df[styles_df['masterCategory'].isin(['Accessories', 'Apparel', 'Footwear', 'Personal Care'])]

# %%
styles_df.groupby('masterCategory')['masterCategory'].count()
# Out:
# masterCategory
# Accessories      11274
# Apparel          21397
# Footwear          9219
# Personal Care     2404
# Name: masterCategory, dtype: int64

# %%
# unique subcategories
print(np.unique(styles_df.subCategory))
# Out:
# ['Accessories' 'Apparel Set' 'Bags' 'Bath and Body' 'Beauty Accessories'
#  'Belts' 'Bottomwear' 'Cufflinks' 'Dress' 'Eyes' 'Eyewear' 'Flip Flops'
#  'Fragrance' 'Gloves' 'Hair' 'Headwear' 'Innerwear' 'Jewellery' 'Lips'
#  'Loungewear and Nightwear' 'Makeup' 'Mufflers' 'Nails' 'Perfumes'
#  'Sandal' 'Saree' 'Scarves' 'Shoe Accessories' 'Shoes' 'Skin' 'Skin Care'
#  'Socks' 'Sports Accessories' 'Stoles' 'Ties' 'Topwear' 'Umbrellas'
#  'Wallets' 'Watches' 'Water Bottle']

# %%
# checking subcategory distribution.
styles_df.groupby('subCategory')['subCategory'].count()
# Out:
# subCategory
# Accessories                   129
# Apparel Set                   106
# Bags                         3055
# Bath and Body                  12
# Beauty Accessories              4
# Belts                         811
# Bottomwear                   2694
# Cufflinks                     108
# Dress                         478
# Eyes                           43
# Eyewear                      1073
# Flip Flops                    913
# Fragrance                    1012
# Gloves                         20
# Hair                           19
# Headwear                      293
# Innerwear                    1808
# Jewellery                    1079
# Lips                          527
# Loungewear and Nightwear      470
# Makeup                        307
# Mufflers                       38
# Nails                         329
# Perfumes                        6
# Sandal                        963
# Saree                         427
# Scarves                       118
# Shoe Accessories               24
# Shoes                        7343
# Skin                           69
# Skin Care                      77
# Socks                         698
# Sports Accessories              3
# Stoles                         90
# Ties                          258
# Topwear                     15402
# Umbrellas                       6
# Wallets                       933
# Watches                      2542
# Water Bottle                    7
# Name: subCategory, dtype: int64

# %%
# for simplicity while training lets delete instances having less than 15 samples
styles_df = styles_df.groupby('subCategory').filter(lambda x : len(x)>20)

# %%
styles_df.groupby('subCategory')['subCategory'].count()
# Out:
# subCategory
# Accessories                   129
# Apparel Set                   106
# Bags                         3055
# Belts                         811
# Bottomwear                   2694
# Cufflinks                     108
# Dress                         478
# Eyes                           43
# Eyewear                      1073
# Flip Flops                    913
# Fragrance                    1012
# Headwear                      293
# Innerwear                    1808
# Jewellery                    1079
# Lips                          527
# Loungewear and Nightwear      470
# Makeup                        307
# Mufflers                       38
# Nails                         329
# Sandal                        963
# Saree                         427
# Scarves                       118
# Shoe Accessories               24
# Shoes                        7343
# Skin                           69
# Skin Care                      77
# Socks                         698
# Stoles                         90
# Ties                          258
# Topwear                     15402
# Wallets                       933
# Watches                      2542
# Name: subCategory, dtype: int64

# %%
styles_df.groupby('articleType')['articleType'].count()
# Out:
# articleType
# Accessory Gift Set      97
# Baby Dolls              16
# Backpacks              722
# Bangle                  85
# Bath Robe               20
#                       ...
# Waist Pouch             17
# Waistcoat               15
# Wallets                935
# Watches               2542
# Water Bottle             4
# Name: articleType, Length: 131, dtype: int64

# %%
# removing items having less than 10
styles_df = styles_df.groupby('articleType').filter(lambda x : len(x)>10)

# %%
styles_df.groupby('articleType')['articleType'].count()
# Out:
# articleType
# Accessory Gift Set      97
# Baby Dolls              16
# Backpacks              722
# Bangle                  85
# Bath Robe               20
#                       ...
# Tunics                 229
# Waist Pouch             17
# Waistcoat               15
# Wallets                935
# Watches               2542
# Name: articleType, Length: 102, dtype: int64

# %%
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44097 entries, 0 to 44424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44097 non-null  int64
#  1   gender              44097 non-null  object
#  2   masterCategory      44097 non-null  object
#  3   subCategory         44097 non-null  object
#  4   articleType         44097 non-null  object
#  5   baseColour          44082 non-null  object
#  6   season              44076 non-null  object
#  7   year                44096 non-null  float64
#  8   usage               43794 non-null  object
#  9   productDisplayName  44090 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.7+ MB

# %%
styles_df.groupby('baseColour')['baseColour'].count()
# Out:
# baseColour
# Beige                 745
# Black                9645
# Blue                 4884
# Bronze                 94
# Brown                3468
# Burgundy               42
# Charcoal              226
# Coffee Brown           31
# Copper                 85
# Cream                 381
# Fluorescent Green       5
# Gold                  621
# Green                2100
# Grey                 2736
# Grey Melange          146
# Khaki                 139
# Lavender              162
# Lime Green              6
# Magenta               128
# Maroon                576
# Mauve                  29
# Metallic               42
# Multi                 392
# Mushroom Brown         16
# Mustard                96
# Navy Blue            1784
# Nude                   23
# Off White             182
# Olive                 407
# Orange                525
# Peach                 195
# Pink                 1844
# Purple               1628
# Red                  2436
# Rose                   27
# Rust                   66
# Sea Green              22
# Silver               1087
# Skin                  176
# Steel                 314
# Tan                   114
# Taupe                  11
# Teal                  120
# Turquoise Blue         68
# White                5491
# Yellow                767
# Name: baseColour, dtype: int64

# %%
# removing items with less than 10 colours
styles_df = styles_df.groupby('baseColour').filter(lambda x : len(x)>10)

# %%
styles_df.groupby('baseColour')['baseColour'].count()
# Out:
# baseColour
# Beige              745
# Black             9645
# Blue              4884
# Bronze              94
# Brown             3468
# Burgundy            42
# Charcoal           226
# Coffee Brown        31
# Copper              85
# Cream              381
# Gold               621
# Green             2100
# Grey              2736
# Grey Melange       146
# Khaki              139
# Lavender           162
# Magenta            128
# Maroon             576
# Mauve               29
# Metallic            42
# Multi              392
# Mushroom Brown      16
# Mustard             96
# Navy Blue         1784
# Nude                23
# Off White          182
# Olive              407
# Orange             525
# Peach              195
# Pink              1844
# Purple            1628
# Red               2436
# Rose                27
# Rust                66
# Sea Green           22
# Silver            1087
# Skin               176
# Steel              314
# Tan                114
# Taupe               11
# Teal               120
# Turquoise Blue      68
# White             5491
# Yellow             767
# Name: baseColour, dtype: int64

# %%
styles_df.groupby('season')['season'].count()
# Out:
# season
# Fall      11381
# Spring     2901
# Summer    21317
# Winter     8451
# Name: season, dtype: int64

# %%
# no need of year column.. delete it
styles_df.groupby('year')['year'].count()
# Out:
# year
# 2007.0        2
# 2008.0        7
# 2009.0       20
# 2010.0      826
# 2011.0    13636
# 2012.0    16173
# 2013.0     1207
# 2014.0      230
# 2015.0     2764
# 2016.0     5936
# 2017.0     2832
# 2018.0      405
# 2019.0       32
# Name: year, dtype: int64

# %%
styles_df = styles_df.drop(columns='year')

# %%
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44071 entries, 0 to 44424
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44071 non-null  int64
#  1   gender              44071 non-null  object
#  2   masterCategory      44071 non-null  object
#  3   subCategory         44071 non-null  object
#  4   articleType         44071 non-null  object
#  5   baseColour          44071 non-null  object
#  6   season              44050 non-null  object
#  7   usage               43777 non-null  object
#  8   productDisplayName  44069 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 3.4+ MB

# %%
styles_df.groupby('usage')['usage'].count()
# Out:
# usage
# Casual          34163
# Ethnic           3175
# Formal           2332
# Party              28
# Smart Casual       67
# Sports           3986
# Travel             26
# Name: usage, dtype: int64

# %%
# removing all items with product display name as null
styles_df = styles_df.dropna(subset=['productDisplayName'])
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44069 entries, 0 to 44424
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44069 non-null  int64
#  1   gender              44069 non-null  object
#  2   masterCategory      44069 non-null  object
#  3   subCategory         44069 non-null  object
#  4   articleType         44069 non-null  object
#  5   baseColour          44069 non-null  object
#  6   season              44048 non-null  object
#  7   usage               43775 non-null  object
#  8   productDisplayName  44069 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 3.4+ MB

# %%
styles_df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#     usage                             productDisplayName
# 0  Casual               Turtle Check Men Navy Blue Shirt
# 1  Casual             Peter England Men Party Blue Jeans
# 2  Casual                       Titan Women Silver Watch
# 3  Casual  Manchester United Men Solid Black Track Pants
# 4  Casual                          Puma Men Grey T-shirt

# %%
styles_df[styles_df['usage'].isnull()]
# Out:
#           id  gender masterCategory               subCategory  \
# 87     56489   Women  Personal Care                     Nails
# 92     52029  Unisex        Apparel                   Topwear
# 292    55001   Women  Personal Care                      Lips
# 479    57563   Women  Personal Care                      Lips
# 511    55006   Women  Personal Care                      Lips
# ...      ...     ...            ...                       ...
# 43569  51044   Women        Apparel  Loungewear and Nightwear
# 43634  56605   Women  Personal Care                    Makeup
# 44080  57715   Women  Personal Care                      Lips
# 44228  55045   Women  Personal Care                      Lips
# 44344   6839  Unisex    Accessories          Shoe Accessories
#
#               articleType    baseColour  season usage  \
# 87            Nail Polish        Bronze  Spring   NaN
# 92            Rain Jacket  Coffee Brown  Summer   NaN
# 292              Lipstick          Pink  Spring   NaN
# 479              Lipstick         Brown  Spring   NaN
# 511             Lip Gloss        Copper  Spring   NaN
# ...                   ...           ...     ...   ...
# 43569          Baby Dolls     Navy Blue  Summer   NaN
# 43634  Kajal and Eyeliner         Black  Spring   NaN
# 44080           Lip Gloss           Red  Spring   NaN
# 44228            Lipstick        Purple  Spring   NaN
# 44344    Shoe Accessories         Black  Winter   NaN
#
#                                       productDisplayName  \
# 87                       Streetwear Ash Nail Polish # 31
# 92              Just Natural Unisex Charcoal Rain Jacket
# 292          Lakme Absolute Lip Last Day Kiss Lip Colour
# 479    Lotus Herbals Pure Colours Nutty Brown Lipstic...
# 511                       Lakme Sheer Satin Lip Gloss 51
# ...                                                  ...
# 43569        Enamor Women Navy Blue Baby Doll Nightdress
# 43634                      Streetwear Black Eye Liner 01
# 44080  Lotus Herbals Seduction Sappy Watermelon Lip G...
# 44228                   Lakme Enrich Satins Lipstick 461
# 44344         Timberland Unisex Waximum Shoe Accessories
#
#                                           productNameNew
# 87                   nan Streetwear Ash Nail Polish # 31
# 92          nan Just Natural Unisex Charcoal Rain Jacket
# 292      nan Lakme Absolute Lip Last Day Kiss Lip Colour
# 479    nan Lotus Herbals Pure Colours Nutty Brown Lip...
# 511                   nan Lakme Sheer Satin Lip Gloss 51
# ...                                                  ...
# 43569    nan Enamor Women Navy Blue Baby Doll Nightdress
# 43634                  nan Streetwear Black Eye Liner 01
# 44080  nan Lotus Herbals Seduction Sappy Watermelon L...
# 44228               nan Lakme Enrich Satins Lipstick 461
# 44344     nan Timberland Unisex Waximum Shoe Accessories
#
# [294 rows x 10 columns]

# %%
styles_df = styles_df.fillna('')

# %%
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44069 entries, 0 to 44424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44069 non-null  int64
#  1   gender              44069 non-null  object
#  2   masterCategory      44069 non-null  object
#  3   subCategory         44069 non-null  object
#  4   articleType         44069 non-null  object
#  5   baseColour          44069 non-null  object
#  6   season              44069 non-null  object
#  7   usage               44069 non-null  object
#  8   productDisplayName  44069 non-null  object
#  9   productNameNew      44069 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.7+ MB

# %%
# Lets remove column usage and merge it with product display name creating new column productNameNew
styles_df['productNameNew'] = styles_df['usage'].astype(str) + ' ' + styles_df['productDisplayName']

# %%
styles_df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#     usage                             productDisplayName  \
# 0  Casual               Turtle Check Men Navy Blue Shirt
# 1  Casual             Peter England Men Party Blue Jeans
# 2  Casual                       Titan Women Silver Watch
# 3  Casual  Manchester United Men Solid Black Track Pants
# 4  Casual                          Puma Men Grey T-shirt
# 5  Casual           Inkfruit Mens Chain Reaction T-shirt
# 6  Ethnic               Fabindia Men Striped Green Shirt
# 7  Casual                  Jealous 21 Women Purple Shirt
# 8  Casual                       Puma Men Pack of 3 Socks
# 9  Casual                         Skagen Men Black Watch
#
#                                       productNameNew
# 0            Casual Turtle Check Men Navy Blue Shirt
# 1          Casual Peter England Men Party Blue Jeans
# 2                    Casual Titan Women Silver Watch
# 3  Casual Manchester United Men Solid Black Track...
# 4                       Casual Puma Men Grey T-shirt
# 5        Casual Inkfruit Mens Chain Reaction T-shirt
# 6            Ethnic Fabindia Men Striped Green Shirt
# 7               Casual Jealous 21 Women Purple Shirt
# 8                    Casual Puma Men Pack of 3 Socks
# 9                      Casual Skagen Men Black Watch

# %%
import re

# %%
# Lets check numbers and special characters from productNameNew
def special_present(x):
    return bool(re.search(r'[\d#!*?.\/]', x))

# %%
styles_df['special_present'] = styles_df['productNameNew'].apply(lambda x : special_present(x))

# %%
styles_df[styles_df.special_present == True]
# Out:
#           id gender masterCategory subCategory             articleType  \
# 7      26960  Women        Apparel     Topwear                  Shirts
# 8      29114    Men    Accessories       Socks                   Socks
# 14     46885   Boys       Footwear  Flip Flops              Flip Flops
# 16     29928    Men    Accessories     Watches                 Watches
# 18     51832  Women        Apparel   Innerwear                     Bra
# ...      ...    ...            ...         ...                     ...
# 44395  37603  Girls        Apparel     Topwear                 Tshirts
# 44397  56634  Women  Personal Care   Skin Care  Face Wash and Cleanser
# 44408  32143    Men        Apparel   Innerwear                  Briefs
# 44414  40563  Women    Accessories     Watches                 Watches
# 44424  51623  Women    Accessories     Watches                 Watches
#
#       baseColour  season   usage  \
# 7         Purple  Summer  Casual
# 8      Navy Blue  Summer  Casual
# 14     Navy Blue    Fall  Casual
# 16         Black  Winter  Casual
# 18         Beige  Summer  Casual
# ...          ...     ...     ...
# 44395     Purple  Summer  Casual
# 44397      Black  Spring  Casual
# 44408        Red  Summer  Casual
# 44414      White  Winter  Casual
# 44424       Pink  Winter  Casual
#
#                                      productDisplayName  \
# 7                         Jealous 21 Women Purple Shirt
# 8                              Puma Men Pack of 3 Socks
# 14                       Ben 10 Boys Navy Blue Slippers
# 16              Police Men Black Dial Watch PL12889JVSB
# 18                 Bwitch Beige Full-Coverage Bra BW335
# ...                                                 ...
# 44395          Madagascar3 Girls Purple Printed T-Shirt
# 44397  Olay Women Total Effects 7 in 1 Foaming Cleanser
# 44408                 Playboy Men Duet Pack of 2 Briefs
# 44414           Titan Women White Dial Watch NB9701WM01
# 44424   Fossil Women Pink Dial Chronograph Watch ES3050
#
#                                           productNameNew  special_present
# 7                   Casual Jealous 21 Women Purple Shirt             True
# 8                        Casual Puma Men Pack of 3 Socks             True
# 14                 Casual Ben 10 Boys Navy Blue Slippers             True
# 16        Casual Police Men Black Dial Watch PL12889JVSB             True
# 18           Casual Bwitch Beige Full-Coverage Bra BW335             True
# ...                                                  ...              ...
# 44395    Casual Madagascar3 Girls Purple Printed T-Shirt             True
# 44397  Casual Olay Women Total Effects 7 in 1 Foaming...             True
# 44408           Casual Playboy Men Duet Pack of 2 Briefs             True
# 44414     Casual Titan Women White Dial Watch NB9701WM01             True
# 44424  Casual Fossil Women Pink Dial Chronograph Watc...             True
#
# [5322 rows x 11 columns]

# %%
def remove_special(x):
    sample = re.sub(r'[\d#!*?.\/]', '', x)
    sample = re.sub(r'\b[A-Z]+\b', '', sample)
    sample = sample.lower()
    return " ".join(sample.split())

# %%
styles_df['cleanProductName'] = styles_df['productNameNew'].apply(lambda x : remove_special(x))

# %%
styles_df.loc[44397]
# Out:
# id                                                                56634
# gender                                                            Women
# masterCategory                                            Personal Care
# subCategory                                                   Skin Care
# articleType                                      Face Wash and Cleanser
# baseColour                                                        Black
# season                                                           Spring
# usage                                                            Casual
# productDisplayName     Olay Women Total Effects 7 in 1 Foaming Cleanser
# productNameNew        Casual Olay Women Total Effects 7 in 1 Foaming...
# special_present                                                    True
# cleanProductName      casual olay women total effects in foaming cle...
# Name: 44397, dtype: object

# %%
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44069 entries, 0 to 44424
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44069 non-null  int64
#  1   gender              44069 non-null  object
#  2   masterCategory      44069 non-null  object
#  3   subCategory         44069 non-null  object
#  4   articleType         44069 non-null  object
#  5   baseColour          44069 non-null  object
#  6   season              44069 non-null  object
#  7   usage               44069 non-null  object
#  8   productDisplayName  44069 non-null  object
#  9   productNameNew      44069 non-null  object
#  10  special_present     44069 non-null  bool
#  11  cleanProductName    44069 non-null  object
# dtypes: bool(1), int64(1), object(10)
# memory usage: 5.1+ MB

# %%
# remove the intermediate columns
styles_df = styles_df.drop(columns=['productDisplayName', 'productNameNew', 'special_present', 'usage'])
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44069 entries, 0 to 44424
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                44069 non-null  int64
#  1   gender            44069 non-null  object
#  2   masterCategory    44069 non-null  object
#  3   subCategory       44069 non-null  object
#  4   articleType       44069 non-null  object
#  5   baseColour        44069 non-null  object
#  6   season            44069 non-null  object
#  7   cleanProductName  44069 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 4.0+ MB

# %%
styles_df[styles_df.season == '']
# Out:
#           id  gender masterCategory subCategory   articleType baseColour  \
# 1903    5376  Unisex       Footwear       Shoes  Sports Shoes      Black
# 6122    5355     Men       Footwear       Shoes  Sports Shoes       Grey
# 9483    5391     Men       Footwear       Shoes  Sports Shoes       Blue
# 10095   5398     Men       Footwear       Shoes  Sports Shoes       Grey
# 10450   5389  Unisex       Footwear       Shoes  Sports Shoes     Yellow
# 11358  53781     Men        Apparel     Topwear       Tshirts       Blue
# 17424   5385   Women       Footwear       Shoes  Sports Shoes       Blue
# 18766   5354     Men       Footwear       Shoes  Sports Shoes       Grey
# 21681   5370     Men       Footwear       Shoes  Sports Shoes      Black
# 22350   5401   Women       Footwear       Shoes  Sports Shoes       Blue
# 26981   5365  Unisex       Footwear       Shoes  Sports Shoes      Green
# 29612   5390  Unisex       Footwear       Shoes  Sports Shoes       Grey
# 31051   5406   Women       Footwear       Shoes  Sports Shoes       Blue
# 31797   5402   Women       Footwear       Shoes  Sports Shoes     Purple
# 32443   5380   Women       Footwear       Shoes  Sports Shoes     Purple
# 32826   5407   Women       Footwear       Shoes  Sports Shoes      Beige
# 32858   5360   Women       Footwear       Shoes  Sports Shoes       Grey
# 35156   5361     Men       Footwear       Shoes  Sports Shoes      Black
# 40924   5368     Men       Footwear       Shoes  Sports Shoes        Red
# 41487   5392  Unisex       Footwear       Shoes  Sports Shoes      White
# 42076   5377  Unisex       Footwear       Shoes  Sports Shoes      Black
#
#       season                              cleanProductName
# 1903                                sports btwin mtb shoes
# 6122                     sports kalenji kapteren greywhite
# 9483                         sports kalenji kiprun blue ah
# 10095             sports quechua arpenaz flex novadry grey
# 10450                    sports kalenji kapteren yellow fw
# 11358         sports puma men blue sless round neck -shirt
# 17424                sports quechua arpenaz flex lady grey
# 18766                        sports kalenji ekiden whtgrey
# 21681                        sports inesis canaveral black
# 22350                      sports kalenji ekiden lady blue
# 26981                          sports solognac shoes namib
# 29612                   sports kalenji kapteren grey orang
# 31051                   sports kalenji ekiden blue scratch
# 31797                      sports kalenji ekiden wn purple
# 32443                   sports quechua forclaz lady purple
# 32826                      sports quechua forclaz beige cn
# 32858                     sports kalenji kapteren bluegrey
# 35156                               sports kipsta fg sr ah
# 40924                   sports kalenji kiprun white red ss
# 41487                    sports kalenji crossport whichamp
# 42076                              sports btwin road shoes

# %%
styles_df.groupby('gender')['gender'].count()
# Out:
# gender
# Boys        818
# Girls       643
# Men       22051
# Unisex     2094
# Women     18463
# Name: gender, dtype: int64

# %%
styles_df = styles_df.sample(frac=1).reset_index(drop=True)

# %%
# save prepared
styles_df.to_csv(os.path.join(data_path, 'final-styles_df.csv'), index=False)

# %%
styles_df = pd.read_csv(os.path.join(data_path, 'final-styles_df.csv'))

# %%
styles_df.loc[styles_df.season == '', 'season'] = 'any'

# %%
styles_df.groupby('season')['season'].count()
# Out:
# season
# Fall      11381
# Spring     2900
# Summer    21313
# Winter     8450
# any          21
# Name: season, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_gender = LabelEncoder()
le_gender.fit(styles_df.gender)
# Out:
# LabelEncoder()

# %%
gender_values = list(le_gender.classes_)
gender_values
# Out:
# ['Boys', 'Girls', 'Men', 'Unisex', 'Women']

# %%
gender_keys = [i for i in range(len(gender_values))]
gender_keys
# Out:
# [0, 1, 2, 3, 4]

# %%
gender_dict = zip(gender_keys, gender_values)
dict(gender_dict)
# Out:
# {0: 'Boys', 1: 'Girls', 2: 'Men', 3: 'Unisex', 4: 'Women'}

# %%
def return_dict(column):
    le = LabelEncoder()
    le.fit(column)
    values = list(le.classes_)
    keys = [i for i in range(len(values))]
    return dict(zip(keys, values)), dict(zip(values, keys))

# %%
gender_dict, gender_inv = return_dict(styles_df.gender)
master_dict, master_inv = return_dict(styles_df.masterCategory)
sub_dict, sub_inv = return_dict(styles_df.subCategory)
article_dict, article_inv = return_dict(styles_df.articleType)
color_dict, color_inv = return_dict(styles_df.baseColour)
season_dict, season_inv = return_dict(styles_df.season)

# %%
gender_dict, master_dict, sub_dict, article_dict, color_dict, season_dict
# Out:
# ({0: 'Boys', 1: 'Girls', 2: 'Men', 3: 'Unisex', 4: 'Women'},
#  {0: 'Accessories', 1: 'Apparel', 2: 'Footwear', 3: 'Personal Care'},
#  {0: 'Accessories',
#   1: 'Apparel Set',
#   2: 'Bags',
#   3: 'Belts',
#   4: 'Bottomwear',
#   5: 'Cufflinks',
#   6: 'Dress',
#   7: 'Eyes',
#   8: 'Eyewear',
#   9: 'Flip Flops',
#   10: 'Fragrance',
#   11: 'Headwear',
#   12: 'Innerwear',
#   13: 'Jewellery',
#   14: 'Lips',
#   15: 'Loungewear and Nightwear',
#   16: 'Makeup',
#   17: 'Mufflers',
#   18: 'Nails',
#   19: 'Sandal',
#   20: 'Saree',
#   21: 'Scarves',
#   22: 'Shoe Accessories',
#   23: 'Shoes',
#   24: 'Skin',
#   25: 'Skin Care',
#   26: 'Socks',
#   27: 'Stoles',
#   28: 'Ties',
#   29: 'Topwear',
#   30: 'Wallets',
#   31: 'Watches'},
#  {0: 'Accessory Gift Set',
#   1: 'Baby Dolls',
#   2: 'Backpacks',
#   3: 'Bangle',
#   4: 'Bath Robe',
#   5: 'Belts',
#   6: 'Booties',
#   7: 'Boxers',
#   8: 'Bra',
#   9: 'Bracelet',
#   10: 'Briefs',
#   11: 'Camisoles',
#   12: 'Capris',
#   13: 'Caps',
#   14: 'Casual Shoes',
#   15: 'Churidar',
#   16: 'Clutches',
#   17: 'Compact',
#   18: 'Concealer',
#   19: 'Cufflinks',
#   20: 'Deodorant',
#   21: 'Dresses',
#   22: 'Duffel Bag',
#   23: 'Dupatta',
#   24: 'Earrings',
#   25: 'Eyeshadow',
#   26: 'Face Moisturisers',
#   27: 'Face Wash and Cleanser',
#   28: 'Flats',
#   29: 'Flip Flops',
#   30: 'Formal Shoes',
#   31: 'Foundation and Primer',
#   32: 'Fragrance Gift Set',
#   33: 'Handbags',
#   34: 'Heels',
#   35: 'Highlighter and Blush',
#   36: 'Innerwear Vests',
#   37: 'Jackets',
#   38: 'Jeans',
#   39: 'Jeggings',
#   40: 'Jewellery Set',
#   41: 'Jumpsuit',
#   42: 'Kajal and Eyeliner',
#   43: 'Kurta Sets',
#   44: 'Kurtas',
#   45: 'Kurtis',
#   46: 'Laptop Bag',
#   47: 'Leggings',
#   48: 'Lip Care',
#   49: 'Lip Gloss',
#   50: 'Lip Liner',
#   51: 'Lipstick',
#   52: 'Lounge Pants',
#   53: 'Lounge Shorts',
#   54: 'Mascara',
#   55: 'Mask and Peel',
#   56: 'Messenger Bag',
#   57: 'Mobile Pouch',
#   58: 'Mufflers',
#   59: 'Nail Polish',
#   60: 'Necklace and Chains',
#   61: 'Night suits',
#   62: 'Nightdress',
#   63: 'Patiala',
#   64: 'Pendant',
#   65: 'Perfume and Body Mist',
#   66: 'Rain Jacket',
#   67: 'Ring',
#   68: 'Rompers',
#   69: 'Rucksacks',
#   70: 'Salwar',
#   71: 'Sandals',
#   72: 'Sarees',
#   73: 'Scarves',
#   74: 'Shirts',
#   75: 'Shoe Accessories',
#   76: 'Shorts',
#   77: 'Skirts',
#   78: 'Socks',
#   79: 'Sports Sandals',
#   80: 'Sports Shoes',
#   81: 'Stockings',
#   82: 'Stoles',
#   83: 'Sunglasses',
#   84: 'Sunscreen',
#   85: 'Suspenders',
#   86: 'Sweaters',
#   87: 'Sweatshirts',
#   88: 'Swimwear',
#   89: 'Ties',
#   90: 'Tops',
#   91: 'Track Pants',
#   92: 'Tracksuits',
#   93: 'Travel Accessory',
#   94: 'Trousers',
#   95: 'Trunk',
#   96: 'Tshirts',
#   97: 'Tunics',
#   98: 'Waist Pouch',
#   99: 'Waistcoat',
#   100: 'Wallets',
#   101: 'Watches'},
#  {0: 'Beige',
#   1: 'Black',
#   2: 'Blue',
#   3: 'Bronze',
#   4: 'Brown',
#   5: 'Burgundy',
#   6: 'Charcoal',
#   7: 'Coffee Brown',
#   8: 'Copper',
#   9: 'Cream',
#   10: 'Gold',
#   11: 'Green',
#   12: 'Grey',
#   13: 'Grey Melange',
#   14: 'Khaki',
#   15: 'Lavender',
#   16: 'Magenta',
#   17: 'Maroon',
#   18: 'Mauve',
#   19: 'Metallic',
#   20: 'Multi',
#   21: 'Mushroom Brown',
#   22: 'Mustard',
#   23: 'Navy Blue',
#   24: 'Nude',
#   25: 'Off White',
#   26: 'Olive',
#   27: 'Orange',
#   28: 'Peach',
#   29: 'Pink',
#   30: 'Purple',
#   31: 'Red',
#   32: 'Rose',
#   33: 'Rust',
#   34: 'Sea Green',
#   35: 'Silver',
#   36: 'Skin',
#   37: 'Steel',
#   38: 'Tan',
#   39: 'Taupe',
#   40: 'Teal',
#   41: 'Turquoise Blue',
#   42: 'White',
#   43: 'Yellow'},
#  {0: 'Fall', 1: 'Spring', 2: 'Summer', 3: 'Winter', 4: 'any'})

# %%
gender_inv, master_inv, sub_inv, article_inv, color_inv, season_inv
# Out:
# ({'Boys': 0, 'Girls': 1, 'Men': 2, 'Unisex': 3, 'Women': 4},
#  {'Accessories': 0, 'Apparel': 1, 'Footwear': 2, 'Personal Care': 3},
#  {'Accessories': 0,
#   'Apparel Set': 1,
#   'Bags': 2,
#   'Belts': 3,
#   'Bottomwear': 4,
#   'Cufflinks': 5,
#   'Dress': 6,
#   'Eyes': 7,
#   'Eyewear': 8,
#   'Flip Flops': 9,
#   'Fragrance': 10,
#   'Headwear': 11,
#   'Innerwear': 12,
#   'Jewellery': 13,
#   'Lips': 14,
#   'Loungewear and Nightwear': 15,
#   'Makeup': 16,
#   'Mufflers': 17,
#   'Nails': 18,
#   'Sandal': 19,
#   'Saree': 20,
#   'Scarves': 21,
#   'Shoe Accessories': 22,
#   'Shoes': 23,
#   'Skin': 24,
#   'Skin Care': 25,
#   'Socks': 26,
#   'Stoles': 27,
#   'Ties': 28,
#   'Topwear': 29,
#   'Wallets': 30,
#   'Watches': 31},
#  {'Accessory Gift Set': 0,
#   'Baby Dolls': 1,
#   'Backpacks': 2,
#   'Bangle': 3,
#   'Bath Robe': 4,
#   'Belts': 5,
#   'Booties': 6,
#   'Boxers': 7,
#   'Bra': 8,
#   'Bracelet': 9,
#   'Briefs': 10,
#   'Camisoles': 11,
#   'Capris': 12,
#   'Caps': 13,
#   'Casual Shoes': 14,
#   'Churidar': 15,
#   'Clutches': 16,
#   'Compact': 17,
#   'Concealer': 18,
#   'Cufflinks': 19,
#   'Deodorant': 20,
#   'Dresses': 21,
#   'Duffel Bag': 22,
#   'Dupatta': 23,
#   'Earrings': 24,
#   'Eyeshadow': 25,
#   'Face Moisturisers': 26,
#   'Face Wash and Cleanser': 27,
#   'Flats': 28,
#   'Flip Flops': 29,
#   'Formal Shoes': 30,
#   'Foundation and Primer': 31,
#   'Fragrance Gift Set': 32,
#   'Handbags': 33,
#   'Heels': 34,
#   'Highlighter and Blush': 35,
#   'Innerwear Vests': 36,
#   'Jackets': 37,
#   'Jeans': 38,
#   'Jeggings': 39,
#   'Jewellery Set': 40,
#   'Jumpsuit': 41,
#   'Kajal and Eyeliner': 42,
#   'Kurta Sets': 43,
#   'Kurtas': 44,
#   'Kurtis': 45,
#   'Laptop Bag': 46,
#   'Leggings': 47,
#   'Lip Care': 48,
#   'Lip Gloss': 49,
#   'Lip Liner': 50,
#   'Lipstick': 51,
#   'Lounge Pants': 52,
#   'Lounge Shorts': 53,
#   'Mascara': 54,
#   'Mask and Peel': 55,
#   'Messenger Bag': 56,
#   'Mobile Pouch': 57,
#   'Mufflers': 58,
#   'Nail Polish': 59,
#   'Necklace and Chains': 60,
#   'Night suits': 61,
#   'Nightdress': 62,
#   'Patiala': 63,
#   'Pendant': 64,
#   'Perfume and Body Mist': 65,
#   'Rain Jacket': 66,
#   'Ring': 67,
#   'Rompers': 68,
#   'Rucksacks': 69,
#   'Salwar': 70,
#   'Sandals': 71,
#   'Sarees': 72,
#   'Scarves': 73,
#   'Shirts': 74,
#   'Shoe Accessories': 75,
#   'Shorts': 76,
#   'Skirts': 77,
#   'Socks': 78,
#   'Sports Sandals': 79,
#   'Sports Shoes': 80,
#   'Stockings': 81,
#   'Stoles': 82,
#   'Sunglasses': 83,
#   'Sunscreen': 84,
#   'Suspenders': 85,
#   'Sweaters': 86,
#   'Sweatshirts': 87,
#   'Swimwear': 88,
#   'Ties': 89,
#   'Tops': 90,
#   'Track Pants': 91,
#   'Tracksuits': 92,
#   'Travel Accessory': 93,
#   'Trousers': 94,
#   'Trunk': 95,
#   'Tshirts': 96,
#   'Tunics': 97,
#   'Waist Pouch': 98,
#   'Waistcoat': 99,
#   'Wallets': 100,
#   'Watches': 101},
#  {'Beige': 0,
#   'Black': 1,
#   'Blue': 2,
#   'Bronze': 3,
#   'Brown': 4,
#   'Burgundy': 5,
#   'Charcoal': 6,
#   'Coffee Brown': 7,
#   'Copper': 8,
#   'Cream': 9,
#   'Gold': 10,
#   'Green': 11,
#   'Grey': 12,
#   'Grey Melange': 13,
#   'Khaki': 14,
#   'Lavender': 15,
#   'Magenta': 16,
#   'Maroon': 17,
#   'Mauve': 18,
#   'Metallic': 19,
#   'Multi': 20,
#   'Mushroom Brown': 21,
#   'Mustard': 22,
#   'Navy Blue': 23,
#   'Nude': 24,
#   'Off White': 25,
#   'Olive': 26,
#   'Orange': 27,
#   'Peach': 28,
#   'Pink': 29,
#   'Purple': 30,
#   'Red': 31,
#   'Rose': 32,
#   'Rust': 33,
#   'Sea Green': 34,
#   'Silver': 35,
#   'Skin': 36,
#   'Steel': 37,
#   'Tan': 38,
#   'Taupe': 39,
#   'Teal': 40,
#   'Turquoise Blue': 41,
#   'White': 42,
#   'Yellow': 43},
#  {'Fall': 0, 'Spring': 1, 'Summer': 2, 'Winter': 3, 'any': 4})

# %%
#### Rough work
styles_df[styles_df.id == 39401]
# Out:
# Empty DataFrame
# Columns: [id, gender, masterCategory, subCategory, articleType, baseColour, season, cleanProductName]
# Index: []

# %%
image_df[image_df.filename == '39401.jpg']
# Out:
#         filename       link
# 32324  39401.jpg  undefined

# %%
undefined_files = image_df[image_df.link == 'undefined']['filename']
undefined_files = list(undefined_files)
undefined_files
# Out:
# ['39403.jpg', '39410.jpg', '39401.jpg', '39425.jpg', '12347.jpg']

# %%
undefined_files = [39403, 39410, 39401, 39425, 12347]

# %%
# the filename with undefined link are not present in the dataset of images.Remove them from styles
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44065 entries, 0 to 44064
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                44065 non-null  int64
#  1   gender            44065 non-null  object
#  2   masterCategory    44065 non-null  object
#  3   subCategory       44065 non-null  object
#  4   articleType       44065 non-null  object
#  5   baseColour        44065 non-null  object
#  6   season            44065 non-null  object
#  7   cleanProductName  44065 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.7+ MB

# %%
styles_df = styles_df[~styles_df['id'].isin(undefined_files)]

# %%
styles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44065 entries, 0 to 44068
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                44065 non-null  int64
#  1   gender            44065 non-null  object
#  2   masterCategory    44065 non-null  object
#  3   subCategory       44065 non-null  object
#  4   articleType       44065 non-null  object
#  5   baseColour        44065 non-null  object
#  6   season            44065 non-null  object
#  7   cleanProductName  44065 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.0+ MB

# %%
styles_df.tail()
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 44064  28559    Men        Apparel     Topwear     Tshirts        Red  Summer
# 44065  56041  Women  Personal Care        Lips    Lipstick      Brown  Spring
# 44066  42209  Women        Apparel       Dress     Dresses     Purple  Summer
# 44067  25534    Men        Apparel     Topwear      Shirts        Red  Summer
# 44068  28563    Men        Apparel     Topwear     Tshirts     Orange  Summer
#
#                                   cleanProductName
# 44064           casual nike men blow up red -shirt
# 44065       casual colorbar coco liscious lipstick
# 44066              casual sepia women purple dress
# 44067  casual wrangler men american flag red shirt
# 44068        casual nike men brushed orange -shirt

# %%
styles_df.to_csv(os.path.join(data_path, 'final-styles_df.csv'), index=False)

# %%
styles_df = pd.read_csv(os.path.join(data_path, 'final-styles_df.csv'))

# %%
## Checking hierarchichal properties of the categories and subcategories. Is the hierarchy strict?
# Create a function to get the hierarchical categories for master, subcat and articletype
gender_dict, gender_inv = return_dict(styles_df.gender)
master_dict, master_inv = return_dict(styles_df.masterCategory)
sub_dict, sub_inv = return_dict(styles_df.subCategory)
article_dict, article_inv = return_dict(styles_df.articleType)
color_dict, color_inv = return_dict(styles_df.baseColour)
season_dict, season_inv = return_dict(styles_df.season)

# %%
gender_inv, master_inv, sub_inv, article_inv, color_inv, season_inv
# Out:
# ({'Boys': 0, 'Girls': 1, 'Men': 2, 'Unisex': 3, 'Women': 4},
#  {'Accessories': 0, 'Apparel': 1, 'Footwear': 2, 'Personal Care': 3},
#  {'Accessories': 0,
#   'Apparel Set': 1,
#   'Bags': 2,
#   'Belts': 3,
#   'Bottomwear': 4,
#   'Cufflinks': 5,
#   'Dress': 6,
#   'Eyes': 7,
#   'Eyewear': 8,
#   'Flip Flops': 9,
#   'Fragrance': 10,
#   'Headwear': 11,
#   'Innerwear': 12,
#   'Jewellery': 13,
#   'Lips': 14,
#   'Loungewear and Nightwear': 15,
#   'Makeup': 16,
#   'Mufflers': 17,
#   'Nails': 18,
#   'Sandal': 19,
#   'Saree': 20,
#   'Scarves': 21,
#   'Shoe Accessories': 22,
#   'Shoes': 23,
#   'Skin': 24,
#   'Skin Care': 25,
#   'Socks': 26,
#   'Stoles': 27,
#   'Ties': 28,
#   'Topwear': 29,
#   'Wallets': 30,
#   'Watches': 31},
#  {'Accessory Gift Set': 0,
#   'Baby Dolls': 1,
#   'Backpacks': 2,
#   'Bangle': 3,
#   'Bath Robe': 4,
#   'Belts': 5,
#   'Booties': 6,
#   'Boxers': 7,
#   'Bra': 8,
#   'Bracelet': 9,
#   'Briefs': 10,
#   'Camisoles': 11,
#   'Capris': 12,
#   'Caps': 13,
#   'Casual Shoes': 14,
#   'Churidar': 15,
#   'Clutches': 16,
#   'Compact': 17,
#   'Concealer': 18,
#   'Cufflinks': 19,
#   'Deodorant': 20,
#   'Dresses': 21,
#   'Duffel Bag': 22,
#   'Dupatta': 23,
#   'Earrings': 24,
#   'Eyeshadow': 25,
#   'Face Moisturisers': 26,
#   'Face Wash and Cleanser': 27,
#   'Flats': 28,
#   'Flip Flops': 29,
#   'Formal Shoes': 30,
#   'Foundation and Primer': 31,
#   'Fragrance Gift Set': 32,
#   'Handbags': 33,
#   'Heels': 34,
#   'Highlighter and Blush': 35,
#   'Innerwear Vests': 36,
#   'Jackets': 37,
#   'Jeans': 38,
#   'Jeggings': 39,
#   'Jewellery Set': 40,
#   'Jumpsuit': 41,
#   'Kajal and Eyeliner': 42,
#   'Kurta Sets': 43,
#   'Kurtas': 44,
#   'Kurtis': 45,
#   'Laptop Bag': 46,
#   'Leggings': 47,
#   'Lip Care': 48,
#   'Lip Gloss': 49,
#   'Lip Liner': 50,
#   'Lipstick': 51,
#   'Lounge Pants': 52,
#   'Lounge Shorts': 53,
#   'Mascara': 54,
#   'Mask and Peel': 55,
#   'Messenger Bag': 56,
#   'Mobile Pouch': 57,
#   'Mufflers': 58,
#   'Nail Polish': 59,
#   'Necklace and Chains': 60,
#   'Night suits': 61,
#   'Nightdress': 62,
#   'Patiala': 63,
#   'Pendant': 64,
#   'Perfume and Body Mist': 65,
#   'Rain Jacket': 66,
#   'Ring': 67,
#   'Rompers': 68,
#   'Rucksacks': 69,
#   'Salwar': 70,
#   'Sandals': 71,
#   'Sarees': 72,
#   'Scarves': 73,
#   'Shirts': 74,
#   'Shoe Accessories': 75,
#   'Shorts': 76,
#   'Skirts': 77,
#   'Socks': 78,
#   'Sports Sandals': 79,
#   'Sports Shoes': 80,
#   'Stockings': 81,
#   'Stoles': 82,
#   'Sunglasses': 83,
#   'Sunscreen': 84,
#   'Suspenders': 85,
#   'Sweaters': 86,
#   'Sweatshirts': 87,
#   'Swimwear': 88,
#   'Ties': 89,
#   'Tops': 90,
#   'Track Pants': 91,
#   'Tracksuits': 92,
#   'Travel Accessory': 93,
#   'Trousers': 94,
#   'Trunk': 95,
#   'Tshirts': 96,
#   'Tunics': 97,
#   'Waist Pouch': 98,
#   'Waistcoat': 99,
#   'Wallets': 100,
#   'Watches': 101},
#  {'Beige': 0,
#   'Black': 1,
#   'Blue': 2,
#   'Bronze': 3,
#   'Brown': 4,
#   'Burgundy': 5,
#   'Charcoal': 6,
#   'Coffee Brown': 7,
#   'Copper': 8,
#   'Cream': 9,
#   'Gold': 10,
#   'Green': 11,
#   'Grey': 12,
#   'Grey Melange': 13,
#   'Khaki': 14,
#   'Lavender': 15,
#   'Magenta': 16,
#   'Maroon': 17,
#   'Mauve': 18,
#   'Metallic': 19,
#   'Multi': 20,
#   'Mushroom Brown': 21,
#   'Mustard': 22,
#   'Navy Blue': 23,
#   'Nude': 24,
#   'Off White': 25,
#   'Olive': 26,
#   'Orange': 27,
#   'Peach': 28,
#   'Pink': 29,
#   'Purple': 30,
#   'Red': 31,
#   'Rose': 32,
#   'Rust': 33,
#   'Sea Green': 34,
#   'Silver': 35,
#   'Skin': 36,
#   'Steel': 37,
#   'Tan': 38,
#   'Taupe': 39,
#   'Teal': 40,
#   'Turquoise Blue': 41,
#   'White': 42,
#   'Yellow': 43},
#  {'Fall': 0, 'Spring': 1, 'Summer': 2, 'Winter': 3, 'any': 4})

# %%
unique_master_cat = master_inv.keys()
unique_master_cat = list(unique_master_cat)
unique_master_cat
# Out:
# ['Accessories', 'Apparel', 'Footwear', 'Personal Care']

# %%
nested_categories = {}
for master_cat in unique_master_cat:
        styles_df_filter = styles_df[styles_df['masterCategory'] == master_cat]
        unique_subcat = list(np.unique(styles_df_filter.subCategory))
        nested_categories[master_cat] =  unique_subcat

# %%
nested_categories
# Out:
# {'Accessories': ['Accessories',
#   'Bags',
#   'Belts',
#   'Cufflinks',
#   'Eyewear',
#   'Headwear',
#   'Jewellery',
#   'Mufflers',
#   'Scarves',
#   'Shoe Accessories',
#   'Socks',
#   'Stoles',
#   'Ties',
#   'Wallets',
#   'Watches'],
#  'Apparel': ['Apparel Set',
#   'Bottomwear',
#   'Dress',
#   'Innerwear',
#   'Loungewear and Nightwear',
#   'Saree',
#   'Socks',
#   'Topwear'],
#  'Footwear': ['Flip Flops', 'Sandal', 'Shoes'],
#  'Personal Care': ['Eyes',
#   'Fragrance',
#   'Lips',
#   'Makeup',
#   'Nails',
#   'Skin',
#   'Skin Care']}

# %%
# checking if there are repeated items in masterCategory. Socks are common in both Apparel and Accessories.
# so, not necessarily nested. But, looks completely nested in article type
full_list = []
count_values = 0
for key in nested_categories.keys():
    count_values = count_values + len(nested_categories[key])
    full_list = full_list + nested_categories[key]
print(full_list)
print(count_values)
print(len(np.unique(full_list)))
# Out:
# ['Accessories', 'Bags', 'Belts', 'Cufflinks', 'Eyewear', 'Headwear', 'Jewellery', 'Mufflers', 'Scarves', 'Shoe Accessories', 'Socks', 'Stoles', 'Ties', 'Wallets', 'Watches', 'Apparel Set', 'Bottomwear', 'Dress', 'Innerwear', 'Loungewear and Nightwear', 'Saree', 'Socks', 'Topwear', 'Flip Flops', 'Sandal', 'Shoes', 'Eyes', 'Fragrance', 'Lips', 'Makeup', 'Nails', 'Skin', 'Skin Care']
# 33
# 32

# %%
styles_df[(styles_df.subCategory == 'Socks') & (styles_df.masterCategory == 'Apparel')]
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 5552   37575  Girls        Apparel       Socks     Booties      Green  Summer
# 6327   37549  Girls        Apparel       Socks     Booties       Pink  Summer
# 9640   37574  Girls        Apparel       Socks     Booties       Pink  Summer
# 12362  37539   Boys        Apparel       Socks     Booties      White  Summer
# 12580  37538   Boys        Apparel       Socks     Booties       Blue  Summer
# 14409  37576  Girls        Apparel       Socks     Booties      White  Summer
# 16764  37512   Boys        Apparel       Socks     Booties       Blue  Summer
# 19431  37511   Boys        Apparel       Socks     Booties     Yellow  Summer
# 19645  37551  Girls        Apparel       Socks     Booties      White  Summer
# 20242  37537   Boys        Apparel       Socks     Booties     Yellow  Summer
# 20935  37550  Girls        Apparel       Socks     Booties      Green  Summer
# 27889  37513   Boys        Apparel       Socks     Booties      White  Summer
#
#                                         cleanProductName
# 5552   casual madagascar infant girls light green boo...
# 6327        casual madagascar infants girls pink booties
# 9640        casual madagascar infants girls pink booties
# 12362       casual madagascar infants boys white booties
# 12580         casual madagascar infant boys blue booties
# 14409       casual madagascar infant girls white booties
# 16764         casual madagascar infant boys blue booties
# 19431       casual madagascar infant boys yellow booties
# 19645       casual madagascar infant girls white booties
# 20242       casual madagascar infant boys yellow booties
# 20935  casual madagascar infant girls light green boo...
# 27889        casual madagascar infant boys white booties

# %%
styles_df[(styles_df.subCategory == 'Socks') & (styles_df.masterCategory == 'Accessories')]
# Out:
#           id  gender masterCategory subCategory articleType baseColour  \
# 29      9351     Men    Accessories       Socks       Socks      Black
# 92     32165   Women    Accessories       Socks       Socks       Pink
# 310    17402     Men    Accessories       Socks       Socks      Multi
# 467    15549     Men    Accessories       Socks       Socks      Black
# 639     9358   Women    Accessories       Socks       Socks        Red
# ...      ...     ...            ...         ...         ...        ...
# 43568  36412     Men    Accessories       Socks       Socks       Grey
# 43668  32023     Men    Accessories       Socks       Socks      Black
# 43676  49302     Men    Accessories       Socks       Socks       Grey
# 43751  17583  Unisex    Accessories       Socks       Socks      White
# 43793  51179     Men    Accessories       Socks       Socks  Navy Blue
#
#        season                                cleanProductName
# 29       Fall  casual puma men sport pack of pairs black sock
# 92     Summer  casual playboy women playmate pink ankle socks
# 310    Summer    casual reid & taylor men stripes multi socks
# 467      Fall                   sports fila men pack of socks
# 639      Fall     casual puma women sport pack of white socks
# ...       ...                                             ...
# 43568  Summer             casual reid & taylor men grey socks
# 43668  Summer         casual playboy men multi coloured socks
# 43676  Summer                  casual arrow men pack of socks
# 43751    Fall                sports unisex pack of crew socks
# 43793  Summer              casual raymond men navy blue socks
#
# [686 rows x 8 columns]

# %% [markdown]
# ## Checking weightage to mitigate imbalance in categories

# %%
styles_df = pd.read_csv(os.path.join(data_path, 'final-styles_df.csv'))

# %%
styles_df
# Out:
#           id  gender masterCategory subCategory         articleType  \
# 0      25856   Women        Apparel     Topwear              Kurtas
# 1       6560  Unisex    Accessories        Bags           Backpacks
# 2      35881    Boys        Apparel     Topwear             Tshirts
# 3      55556   Women  Personal Care      Makeup  Kajal and Eyeliner
# 4      11291     Men        Apparel  Bottomwear               Jeans
# ...      ...     ...            ...         ...                 ...
# 44060  28559     Men        Apparel     Topwear             Tshirts
# 44061  56041   Women  Personal Care        Lips            Lipstick
# 44062  42209   Women        Apparel       Dress             Dresses
# 44063  25534     Men        Apparel     Topwear              Shirts
# 44064  28563     Men        Apparel     Topwear             Tshirts
#
#       baseColour  season                                   cleanProductName
# 0          Black  Summer         ethnic diva women black floral print kurti
# 1          Black  Winter       casual nike unisex all access black backpack
# 2           Blue  Summer  casual jungle book boys jungle friends blue -s...
# 3          Black  Spring  casual revlon colorstay black beauty liquid ey...
# 4           Blue  Summer             casual wrangler men blue millard jeans
# ...          ...     ...                                                ...
# 44060        Red  Summer                 casual nike men blow up red -shirt
# 44061      Brown  Spring             casual colorbar coco liscious lipstick
# 44062     Purple  Summer                    casual sepia women purple dress
# 44063        Red  Summer        casual wrangler men american flag red shirt
# 44064     Orange  Summer              casual nike men brushed orange -shirt
#
# [44065 rows x 8 columns]

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
# weightage for masterCategory
styles_df.groupby('masterCategory')['masterCategory'].count()
# Out:
# masterCategory
# Accessories      11206
# Apparel          21316
# Footwear          9217
# Personal Care     2326
# Name: masterCategory, dtype: int64

# %%
np.unique(styles_df.masterCategory)
# Out:
# array(['Accessories', 'Apparel', 'Footwear', 'Personal Care'],
#       dtype=object)

# %%
weights = compute_class_weight(class_weight='balanced', classes=np.unique(styles_df.masterCategory), y=np.array(styles_df.masterCategory))
weights
# Out:
# array([0.98306711, 0.51680662, 1.19520994, 4.736135  ])

# %%
# weightage for subcategory
np.unique(styles_df.subCategory)
# Out:
# array(['Accessories', 'Apparel Set', 'Bags', 'Belts', 'Bottomwear',
#        'Cufflinks', 'Dress', 'Eyes', 'Eyewear', 'Flip Flops', 'Fragrance',
#        'Headwear', 'Innerwear', 'Jewellery', 'Lips',
#        'Loungewear and Nightwear', 'Makeup', 'Mufflers', 'Nails',
#        'Sandal', 'Saree', 'Scarves', 'Shoe Accessories', 'Shoes', 'Skin',
#        'Skin Care', 'Socks', 'Stoles', 'Ties', 'Topwear', 'Wallets',
#        'Watches'], dtype=object)

# %%
styles_df.groupby('subCategory')['subCategory'].count()
# Out:
# subCategory
# Accessories                   122
# Apparel Set                    98
# Bags                         3044
# Belts                         811
# Bottomwear                   2669
# Cufflinks                     106
# Dress                         478
# Eyes                           43
# Eyewear                      1073
# Flip Flops                    913
# Fragrance                    1004
# Headwear                      283
# Innerwear                    1799
# Jewellery                    1079
# Lips                          523
# Loungewear and Nightwear      462
# Makeup                        303
# Mufflers                       38
# Nails                         329
# Sandal                        963
# Saree                         427
# Scarves                       118
# Shoe Accessories               23
# Shoes                        7341
# Skin                           63
# Skin Care                      61
# Socks                         698
# Stoles                         90
# Ties                          258
# Topwear                     15371
# Wallets                       933
# Watches                      2542
# Name: subCategory, dtype: int64

# %%
weights = compute_class_weight(class_weight='balanced', classes=np.unique(styles_df.subCategory), y=np.array(styles_df.subCategory))
weights
# Out:
# array([11.28714139, 14.05133929,  0.45237557,  1.69794236,  0.51593528,
#        12.99086085,  2.88081851, 32.02398256,  1.28334692,  1.5082489 ,
#         1.37154507,  4.86583481,  0.76544261,  1.27621061,  2.63294694,
#         2.98058712,  4.54465759, 36.23766447,  4.18550532,  1.42993899,
#         3.22489754, 11.66975636, 59.87092391,  0.18758088, 21.85763889,
#        22.57428279,  1.97282414, 15.30034722,  5.33733043,  0.08958632,
#         1.47591774,  0.54171174])

# %%
# weightage for gender
print(styles_df.groupby('gender')['gender'].count())
print(np.unique(styles_df.gender))
weights = compute_class_weight(class_weight='balanced', classes=np.unique(styles_df.gender), y=np.array(styles_df.gender))
print(weights)
# Out:
# gender
# Boys        818
# Girls       643
# Men       22047
# Unisex     2094
# Women     18463
# Name: gender, dtype: int64
# ['Boys' 'Girls' 'Men' 'Unisex' 'Women']
# [10.77383863 13.70606532  0.39973693  4.2086915   0.47733304]

# %%
weights
# Out:
# array([10.77383863, 13.70606532,  0.39973693,  4.2086915 ,  0.47733304])

# %%
# weightage for color
print(styles_df.groupby('baseColour')['baseColour'].count())
print(np.unique(styles_df.baseColour))
weights = compute_class_weight(class_weight='balanced', classes=np.unique(styles_df.baseColour), y=np.array(styles_df.baseColour))
print(weights)
# Out:
# baseColour
# Beige              745
# Black             9644
# Blue              4883
# Bronze              94
# Brown             3467
# Burgundy            42
# Charcoal           226
# Coffee Brown        31
# Copper              85
# Cream              380
# Gold               621
# Green             2100
# Grey              2736
# Grey Melange       146
# Khaki              139
# Lavender           162
# Magenta            128
# Maroon             575
# Mauve               29
# Metallic            42
# Multi              392
# Mushroom Brown      16
# Mustard             96
# Navy Blue         1784
# Nude                23
# Off White          182
# Olive              407
# Orange             525
# Peach              195
# Pink              1844
# Purple            1628
# Red               2435
# Rose                27
# Rust                66
# Sea Green           22
# Silver            1087
# Skin               176
# Steel              314
# Tan                114
# Taupe               11
# Teal               120
# Turquoise Blue      68
# White             5491
# Yellow             767
# Name: baseColour, dtype: int64
# ['Beige' 'Black' 'Blue' 'Bronze' 'Brown' 'Burgundy' 'Charcoal'
#  'Coffee Brown' 'Copper' 'Cream' 'Gold' 'Green' 'Grey' 'Grey Melange'
#  'Khaki' 'Lavender' 'Magenta' 'Maroon' 'Mauve' 'Metallic' 'Multi'
#  'Mushroom Brown' 'Mustard' 'Navy Blue' 'Nude' 'Off White' 'Olive'
#  'Orange' 'Peach' 'Pink' 'Purple' 'Red' 'Rose' 'Rust' 'Sea Green' 'Silver'
#  'Skin' 'Steel' 'Tan' 'Taupe' 'Teal' 'Turquoise Blue' 'White' 'Yellow']
# [ 1.3442648   0.10384459  0.20509467 10.65401354  0.2888599  23.84469697
#   4.43131537 32.30571848 11.78208556  2.63546651  1.61268482  0.47689394
#   0.36603701  6.85943337  7.20487247  6.18195847  7.82404119  1.7416996
#  34.53369906 23.84469697  2.55478896 62.59232955 10.43205492  0.56136618
#  43.54249012  5.50262238  2.46063212  1.90757576  5.13578089  0.54310047
#   0.61515803  0.4112843  37.09175084 15.17389807 45.52169421  0.92132224
#   5.69021178  3.18941807  8.78488836 91.04338843  8.34564394 14.72760695
#   0.18238523  1.305707  ]

# %%
weights
# Out:
# array([ 1.3442648 ,  0.10384459,  0.20509467, 10.65401354,  0.2888599 ,
#        23.84469697,  4.43131537, 32.30571848, 11.78208556,  2.63546651,
#         1.61268482,  0.47689394,  0.36603701,  6.85943337,  7.20487247,
#         6.18195847,  7.82404119,  1.7416996 , 34.53369906, 23.84469697,
#         2.55478896, 62.59232955, 10.43205492,  0.56136618, 43.54249012,
#         5.50262238,  2.46063212,  1.90757576,  5.13578089,  0.54310047,
#         0.61515803,  0.4112843 , 37.09175084, 15.17389807, 45.52169421,
#         0.92132224,  5.69021178,  3.18941807,  8.78488836, 91.04338843,
#         8.34564394, 14.72760695,  0.18238523,  1.305707  ])
